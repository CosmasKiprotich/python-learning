# %%
friends = ["cosmas ", "TOm", "Nick", "carent"]
print(friends)
# Out:
# ['cosmas ', 'TOm', 'Nick', 'carent']

# %%
lucky_number = [4,6,233,5,4,7,9,1,22,34,78,90,78,90,89,56,45,45,34,12,13,15]

friends = [
    "John",
    "Mary",
    "Peter",
    "Jane",
    "David",
    "Grace",
    "Brian",
    "Lucy",
    "Kevin",
    "Ann"
]

print(friends)
friends.insert(10,"Karonei")
friends.remove("John")
print(friends)

friends.sort()
print(friends)
friends.reverse()
print(friends)

lucky_number.sort()
print(lucky_number)

luck_number2 = lucky_number.copy()
luck_number2.sort()
print(luck_number2)
# Out:
# ['John', 'Mary', 'Peter', 'Jane', 'David', 'Grace', 'Brian', 'Lucy', 'Kevin', 'Ann']
# ['Mary', 'Peter', 'Jane', 'David', 'Grace', 'Brian', 'Lucy', 'Kevin', 'Ann', 'Karonei']
# ['Ann', 'Brian', 'David', 'Grace', 'Jane', 'Karonei', 'Kevin', 'Lucy', 'Mary', 'Peter']
# ['Peter', 'Mary', 'Lucy', 'Kevin', 'Karonei', 'Jane', 'Grace', 'David', 'Brian', 'Ann']
# [1, 4, 4, 5, 6, 7, 9, 12, 13, 15, 22, 34, 34, 45, 45, 56, 78, 78, 89, 90, 90, 233]
# [1, 4, 4, 5, 6, 7, 9, 12, 13, 15, 22, 34, 34, 45, 45, 56, 78, 78, 89, 90, 90, 233]

# %%
print(lucky_number)
# Out:
# [1, 4, 4, 5, 6, 7, 9, 12, 13, 15, 22, 34, 34, 45, 45, 56, 78, 78, 89, 90, 90, 233]

# %%
coordinates = ((10, 20), (15, 25), (20, 30), (25, 35), (30, 40), (35, 45), (40, 50), (45, 55), (50, 60), (55, 65))
print(coordinates)
print(coordinates[9])
print(coordinates[5])
print(coordinates[4])
print(coordinates[0])
# Out:
# ((10, 20), (15, 25), (20, 30), (25, 35), (30, 40), (35, 45), (40, 50), (45, 55), (50, 60), (55, 65))
# (55, 65)
# (35, 45)
# (30, 40)
# (10, 20)

# %%
#functions

def greetings(first_name, age): #function's name
    message =input("Enter your greetings to : " + first_name)
    print(message)
    if age <= 18:
        print(message + "!!! " + " "+ first_name + " Your under 18, you are not allowed here")
        print("_____________________Run for your Life____________________________________")

    else:
        print(message + "!!!  " + " "+  first_name + " You are allowed here, because you are over 18 years old")
        print("____________________You are welcomed____________________________________")

greetings("Cosmas", 35)
greetings("Steve", 18)
greetings("Denni", 16)
greetings("Mathew", 50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 14
#      10     else:
#      11         print(message + "!!!  " + " "+  first_name + " You are allowed here, because you are over 18 years old")
#      12         print("____________________You are welcomed____________________________________")
#      13
# ---> 14 greetings("Cosmas", 35)
#      15 greetings("Steve", 18)
#      16 greetings("Denni", 16)
#      17 greetings("Mathew", 50)
#
# Cell In[31], line 4, in greetings(first_name, age)
#       3 def greetings(first_name, age): #function's name
# ----> 4     message =input("Enter your greetings to : " + first_name)
#       5     print(message)
#       6     if age <= 18:
#       7         print(message + "!!! " + " "+ first_name + " Your under 18, you are not allowed here")
#
# File ~\PycharmProjects\PythonProject\AI_Ecology\.venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\PycharmProjects\PythonProject\AI_Ecology\.venv\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#using python functions with return statements
def cube(number):

    return number ** 3
cube(5)
# Out:
# 125

# %%
#if statements
#create a boolean variable

is_male = False
is_tall = False

if is_male or is_tall:
    print("You are a male or tall or both")
else:
    print("You are neither male nor tall nor both")


if is_male and is_tall:
    print("You are a male and tall")
else:
    print("You are neither male nor tall nor both")
# Out:
# You are neither male nor tall nor both
# You are neither male nor tall nor both

# %%
is_male = True
is_tall = False

if is_male and is_tall:
    print("You are a tall male")
elif is_male and not(is_tall):
    print("Your are a short male")
elif not is_male and is_tall:
    print("You are a not a male but  tall")
else:
    print("You are neither male nor tall nor both")
# Out:
# Your are a short male

# %%
#Using comparisons in if statements
#determining the largest number and smallest number


def maximum_num(num1, num2, num3):
    if num1 >= num2 and num1 >= num3:
        return num1
    elif num2 >= num1 and num2 >= num3:
        return num2
    else:
        return num3

def minimum_num(num1, num2, num3):
    if num1 <= num2 and num1 <= num3:
        return num1
    elif num2 <= num1 and num2 <= num3:
        return num2
    else:
        return num3


print("The maximum number is " + str(maximum_num(2,2,4)))
print("The minimum number is " + str(minimum_num(2,2,4)))

print("The maximum number is " + str(maximum_num(300,20000,4400)))
print("The minimum number is " + str(minimum_num(300,20000,4400)))
# Out:
# The maximum number is 4
# The minimum number is 2
# The maximum number is 20000
# The minimum number is 300

# %%
#building a basic calculator
#user inputs

num1 = float(input("Enter your first number: "))
op = input("Enter your operation: ")
num2 = float(input("Enter your second number: "))

if op == "+":
    print(num1 + num2)
elif op == "-":
    print(num1 - num2)
elif op == "*":
    print(num1 * num2)
elif op == "/":
    print(num1 / num2)
else:
    print("Invalid operation")
# Out:
# 1.0

# %%
#Dictionaries

monthConversions = {
    "Jan" : "January",
    "Feb" : "February",
    "Mar" : "March",
    "Apr" : "April",
    "May" : "May",
    "Jun" : "June",
    "Jul" : "July",
    "Aug" : "August",
    "Sep" : "September",
    "Oct" : "October",
    "Nov" : "November",
    "Dec" : "December"
}
# for i in monthConversions:
#      print(monthConversions[i])

print(monthConversions["Jan"])
print(monthConversions["Dec"])


print(monthConversions.get("Luv", "Not a valid key"))
# Out:
# January
# December
# Not a valid key

# %%
#While loop
